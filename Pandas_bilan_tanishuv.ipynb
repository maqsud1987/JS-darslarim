# %% [markdown]
# <a href="https://colab.research.google.com/github/maqsud1987/JS-darslarim/blob/main/Pandas_bilan_tanishuv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from pandas import Series # series ma'lumotlar tuzilmasi

obj = Series([4, 5, 6, -6.7])
print(obj)
# Out:
# 0    4.0
# 1    5.0
# 2    6.0
# 3   -6.7
# dtype: float64

# %%
obj.values
# Out:
# array([ 4. ,  5. ,  6. , -6.7])

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj2 = Series([4, 5, 6, -6.7], index=['a', 'b', 'c', 'd'])
obj2
# Out:
# a    4.0
# b    5.0
# c    6.0
# d   -6.7
# dtype: float64

# %%
obj2
# Out:
# a    4.0
# b    5.0
# c    6.0
# d   -6.7
# dtype: float64

# %%
obj2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
obj2['d']
# Out:
# np.float64(-6.7)

# %%
obj2[obj2>2]
# Out:
# a    4.0
# b    5.0
# c    6.0
# dtype: float64

# %%
cars_dictionary = {'Malibu':40000, 'Lacetti':20000, 'Toyota':10000, 'Mazda':5000}
cars = Series(cars_dictionary)
cars
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     10000
# Mazda       5000
# dtype: int64

# %%
cars_dictionary = {'Malibu':40000, 'Lacetti':20000, 'Toyota':10000, 'Mazda':5000}
cars = Series(cars_dictionary)
cars
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     10000
# Mazda       5000
# dtype: int64

# %%
cars_dictionary = {'Malibu':40000, 'Lacetti':20000, 'Toyota':10000, 'Mazda':5000}
cars = Series(cars_dictionary)
cars
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     10000
# Mazda       5000
# dtype: int64

# %%
cars_dictionary = {'Malibu':40000, 'Lacetti':20000, 'Toyota':10000, 'Mazda':5000}
cars = Series(cars_dictionary)
cars
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     10000
# Mazda       5000
# dtype: int64

# %%
"Malibu" in cars_dictionary
# Out:
# True

# %%
'Malibu' in cars
# Out:
# True

# %%
cars1 = Series({'Malibu':40000, 'Lacetti':20000, 'Toyota':10000, 'Mazda':5000})
cars1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     10000
# Mazda       5000
# dtype: int64

# %%
'Toyota' in  cars1
# Out:
# True

# %%
'BMW' in cars1
# Out:
# False

# %%
models = ['Honda', 'Mazda', 'Lacetti', 'Jaguar', 'Malibu', 'Toyota''Chevrolet','Lada']
cars2 = Series(cars_dictionary, index=models)
cars2
# Out:
# Honda                  NaN
# Mazda               5000.0
# Lacetti            20000.0
# Jaguar                 NaN
# Malibu             40000.0
# ToyotaChevrolet        NaN
# Lada                   NaN
# dtype: float64
